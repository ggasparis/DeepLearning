# %% [markdown]
# ## Deep Learning

# %% [markdown]
# ### Στόχος άσκησης
#
# Στόχος αυτής της εργασίας είναι να βελτιστοποιήσουμε την απόδοση μοντέλων Βαθιάς Μάθησης στο σύνολο δεδομένων CIFAR-100 χρησιμοποιώντας την βιβλιοθήκη TensorFlow 2. Δουλεύουμε σε ένα υποσύνολο δεδομένων του CIFAR-100 που αντιστοιχεί με μοναδικό τρόπο στην ομάδα μας, θέτοντας στο team_seed τον αντίστοιχο αριθμό.

# %% [markdown]
# ### Σύνολο δεδομένων CIFAR
#
# Τα σύνολα δεδομένων [CIFAR-10 και CIFAR-100](https://www.cs.toronto.edu/~kriz/cifar.html) χρησιμοποιούνται συχνά στην κοινότητα των νευρωνικών δικτύων. Αποτελούσαν αρχικά σύνολα δεδομένων διαγωνισμών.
#
# Το CIFAR-10 είναι ένα σύνολο δεδομένων από εικόνες χαμηλής ανάλησης που ανήκουν σε 10 κλάσεις. Το CIFAR-100 περιέχει 100 κλάσεις σε ιεραρχικές κατηγορίες.

# %%
# !pip install -q --upgrade pip
# !pip install -q --upgrade tensorflow
# !pip install -q pyyaml h5py  
# !pip install -U keras-tuner

# %% [markdown]
# ## Εισαγωγή και επισκόπηση του συνόλου δεδομένων

# %%
from __future__ import absolute_import, division, print_function, unicode_literals # legacy compatibility

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from kerastuner.tuners import RandomSearch

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
# helper functions

# select from from_list elements with index in index_list
def select_from_list(from_list, index_list):
  filtered_list= [from_list[i] for i in index_list]
  return(filtered_list)

# append in filtered_list the index of each element of unfilterd_list if it exists in in target_list
def get_ds_index(unfiliterd_list, target_list):
  index = 0
  filtered_list=[]
  for i_ in unfiliterd_list:
    if i_[0] in target_list:
      filtered_list.append(index)
    index += 1
  return(filtered_list)

# select a url for a unique subset of CIFAR-100 with 20, 40, 60, or 80 classes
def select_classes_number(classes_number = 20):
  cifar100_20_classes_url = "https://pastebin.com/raw/nzE1n98V"
  cifar100_40_classes_url = "https://pastebin.com/raw/zGX4mCNP"
  cifar100_60_classes_url = "https://pastebin.com/raw/nsDTd3Qn"
  cifar100_80_classes_url = "https://pastebin.com/raw/SNbXz700"
  if classes_number == 20:
    return cifar100_20_classes_url
  elif classes_number == 40:
    return cifar100_40_classes_url
  elif classes_number == 60:
    return cifar100_60_classes_url
  elif classes_number == 80:
    return cifar100_80_classes_url
  else:
    return -1

# %%
# load the entire dataset
(x_train_all, y_train_all), (x_test_all, y_test_all) = tf.keras.datasets.cifar100.load_data(label_mode='fine')

# %%
print(x_train_all.shape)
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# Η κάθε ομάδα θα δουλέψει με ένα μοναδικό ξεχωριστό υποσύνολο του CIFAR-100
# Στο επόμενο κελί, αντικαταστήστε την τιμή της μεταβλητής `team_seed` με τον αριθμό της ομάδας σας.

# %%
# REPLACE WITH YOUR TEAM NUMBER
team_seed = 32

# %% [markdown]
# Στο επόμενο κελί μπορείτε να διαλέξετε το πλήθος των κατηγορίων σας: 20 (default), 40, 60 ή 80.

# %%
# select the number of classes
cifar100_classes_url = select_classes_number()

# %% [markdown]
# Δημιουργούμε το μοναδικό dataset της ομάδας μας:

# %%
team_classes = pd.read_csv(cifar100_classes_url, sep=',', header=None)
CIFAR100_LABELS_LIST = pd.read_csv('https://pastebin.com/raw/qgDaNggt', sep=',', header=None).astype(str).values.tolist()[0]

our_index = team_classes.iloc[team_seed,:].values.tolist()
our_classes = select_from_list(CIFAR100_LABELS_LIST, our_index)
train_index = get_ds_index(y_train_all, our_index)
test_index = get_ds_index(y_test_all, our_index)

x_train_ds = np.asarray(select_from_list(x_train_all, train_index))
y_train_ds = np.asarray(select_from_list(y_train_all, train_index))
x_test_ds = np.asarray(select_from_list(x_test_all, test_index))
y_test_ds = np.asarray(select_from_list(y_test_all, test_index))

# %%
# print our classes
print(our_classes)
# Out:
# [' bear', ' beaver', ' bee', ' beetle', ' camel', ' caterpillar', ' girl', ' house', ' kangaroo', ' leopard', ' plain', ' raccoon', ' seal', ' snail', ' spider', ' streetcar', ' sweet_pepper', ' tank', ' tiger', ' turtle']

# %%
CLASSES_NUM=len(our_classes)

# %%
print(x_train_ds[1].shape)
# Out:
# (32, 32, 3)

# %%
# get (train) dataset dimensions
data_size, img_rows, img_cols, img_channels = x_train_ds.shape

# set validation set percentage (wrt the training set size)
validation_percentage = 0.15
val_size = round(validation_percentage * data_size)

# Reserve val_size samples for validation and normalize all values
x_val = x_train_ds[-val_size:]/255
y_val = y_train_ds[-val_size:]
x_train = x_train_ds[:-val_size]/255
y_train = y_train_ds[:-val_size]
x_test = x_test_ds/255
y_test = y_test_ds

print(len(x_val))

# summarize loaded dataset
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

# get class label from class index
def class_label_from_index(fine_category):
  return(CIFAR100_LABELS_LIST[fine_category.item(0)])

# plot first few images
plt.figure(figsize=(6, 6))
for i in range(9):
	# define subplot
  plt.subplot(330 + 1 + i).set_title(class_label_from_index(y_train[i]))
	# plot raw pixel data
  plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
  #show the figure
plt.show()
# Out:
# 1500
# Train: X=(8500, 32, 32, 3), y=(8500, 1)
# Validation: X=(1500, 32, 32, 3), y=(1500, 1)
# Test: X=(2000, 32, 32, 3), y=(2000, 1)

# %% [markdown]
# ## Συναρτήσεις εκπαίδευσης

# %% [markdown]
# Θα χρησιμοποιήσουμε την ιδιότητα data prefetch του tf2:

# %%
# we user prefetch https://www.tensorflow.org/api_docs/python/tf/data/Dataset#prefetch 
# see also AUTOTUNE
# the dataset is now "infinite"
from keras.callbacks import EarlyStopping, ModelCheckpoint

BATCH_SIZE = 128
AUTOTUNE = tf.data.experimental.AUTOTUNE # https://www.tensorflow.org/guide/data_performance

def _input_fn(x,y, BATCH_SIZE):
  ds = tf.data.Dataset.from_tensor_slices((x,y))
  ds = ds.shuffle(buffer_size=data_size)
  ds = ds.repeat()
  ds = ds.batch(BATCH_SIZE)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds
'''
train_datagen = ImageDataGenerator(
    rotation_range=45,
    width_shift_range=0.15,
    height_shift_range=0.15,
    zoom_range=0.5,
    horizontal_flip=True,
)
train_datagen.fit(x_train)  
'''
train_ds =_input_fn(x_train,y_train, BATCH_SIZE) #PrefetchDataset object
validation_ds =_input_fn(x_val,y_val, BATCH_SIZE) #PrefetchDataset object
test_ds =_input_fn(x_test,y_test, BATCH_SIZE) #PrefetchDataset object

# steps_per_epoch and validation_steps for training and validation: https://www.tensorflow.org/guide/keras/train_and_evaluate

datagen = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True)
train_generator = datagen.flow(x_train, y_train, batch_size=BATCH_SIZE)


callbacks = [EarlyStopping(monitor='val_loss', patience=10),
             ModelCheckpoint(filepath='best_model.h5', monitor='val_loss', save_best_only=True),
             tensorboard_callback]


def train_model(model, epochs = 10, steps_per_epoch = 2, validation_steps = 1):
  #history = model.fit_generator(train_generator, epochs=epochs, steps_per_epoch=steps_per_epoch, validation_data=validation_ds, validation_steps=validation_steps, callbacks=callbacks)
  history = model.fit(train_ds, epochs=epochs, steps_per_epoch=steps_per_epoch, validation_data=validation_ds, validation_steps=validation_steps, callbacks=callbacks)
  return(history)

#call for keras tuner
def train_model_tune(tuner, epochs = 10, steps_per_epoch = 2, validation_steps = 1):
  history = tuner.search(train_ds, epochs=epochs, steps_per_epoch=steps_per_epoch, validation_data=validation_ds, validation_steps=validation_steps)
  return(history)

# %% [markdown]
# ## Γραφικές παραστάσεις εκπαίδευσης και απόδοση στο σύνολο ελέγχου

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
	plt.figure(figsize=(8, 8))
	plt.suptitle('Training Curves')
	# plot loss
	plt.subplot(211)
	plt.title('Cross Entropy Loss')
	plt.plot(history.history['loss'], color='blue', label='train')
	plt.plot(history.history['val_loss'], color='orange', label='val')
	plt.legend(loc='upper right')
	# plot accuracy
	plt.subplot(212)
	plt.title('Classification Accuracy')
	plt.plot(history.history['accuracy'], color='blue', label='train')
	plt.plot(history.history['val_accuracy'], color='orange', label='val')
	plt.legend(loc='lower right')
	return plt
 
# print test set evaluation metrics
def model_evaluation(model, evaluation_steps):
	print('\nTest set evaluation metrics')
	loss0,accuracy0 = model.evaluate(test_ds, steps = evaluation_steps)
	print("loss: {:.2f}".format(loss0))
	print("accuracy: {:.2f}".format(accuracy0))

def model_report(model, history, evaluation_steps = 10):
	plt = summarize_diagnostics(history)
	plt.show()
	model_evaluation(model, evaluation_steps)

# %% [markdown]
# ## Μοντέλα δικτύων

# %% [markdown]
# ### Ένα μικρό συνελικτικό δίκτυο "from scratch"

# %%
# a simple CNN https://www.tensorflow.org/tutorials/images/cnn
dropout_layer = tf.keras.layers.Dropout(rate = 0.2)

def init_simple_model(hp):
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32,32,3)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Flatten())
  model.add(layers.Dense(units=hp.Int('units',min_value=64,max_value=512,step=32), activation='relu'))
  model.add(layers.Dense(100, activation='softmax'))
  model.compile(optimizer=tf.optimizers.Adam(hp.Choice('learning_rate',values=[1e-2, 1e-3, 1e-4])), 
                loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=["accuracy"])
  return model

# %%
# a simple CNN https://www.tensorflow.org/tutorials/images/cnn
dropout_layer = tf.keras.layers.Dropout(rate = 0.5)
def init_simple_model(summary):
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(dropout_layer)
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(dropout_layer)
  model.add(layers.Flatten())
  model.add(layers.Dense(384, activation='relu'))
  model.add(layers.Dense(100, activation='softmax'))
  model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.001), loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=["accuracy"])
  if summary: 
    model.summary()
  return model

start = time.time()

end = time.time()
print("Time elapsed:")
print(end - start)
# Out:
# Time elapsed:
# 3.314018249511719e-05

# %%
SIMPLE_MODEL = init_simple_model(summary = True)
SIMPLE_MODEL_history = train_model(SIMPLE_MODEL, 50, 30, 5)
model_report(SIMPLE_MODEL, SIMPLE_MODEL_history, 30)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          multiple                  0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 384)               393600
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               38500
# =================================================================
# Total params: 488,420
# Trainable params: 488,420
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 30/30 [==============================] - 1s 19ms/step - loss: 3.6760 - accuracy: 0.0447 - val_loss: 2.9676 - val_accuracy: 0.1125
# Epoch 2/50
# 30/30 [==============================] - 0s 11ms/step - loss: 2.8843 - accuracy: 0.1136 - val_loss: 2.7858 - val_accuracy: 0.1422
# Epoch 3/50
# 30/30 [==============================] - 0s 11ms/step - loss: 2.7472 - accuracy: 0.1542 - val_loss: 2.6973 - val_accuracy: 0.1641
# Epoch 4/50
# 30/30 [==============================] - 0s 11ms/step - loss: 2.6598 - accuracy: 0.1732 - val_loss: 2.6600 - val_accuracy: 0.2078
# Epoch 5/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5560 - accuracy: 0.1998 - val_loss: 2.6017 - val_accuracy: 0.2094
# Epoch 6/50
# 30/30 [==============================] - 0s 11ms/step - loss: 2.4730 - accuracy: 0.2413 - val_loss: 2.4747 - val_accuracy: 0.2453
# Epoch 7/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.3745 - accuracy: 0.2714 - val_loss: 2.4112 - val_accuracy: 0.2422
# Epoch 8/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2778 - accuracy: 0.2980 - val_loss: 2.3948 - val_accuracy: 0.2781
# Epoch 9/50
# 30/30 [==============================] - 0s 11ms/step - loss: 2.2417 - accuracy: 0.3151 - val_loss: 2.2578 - val_accuracy: 0.2969
# Epoch 10/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.1724 - accuracy: 0.3418 - val_loss: 2.2294 - val_accuracy: 0.3031
# Epoch 11/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.1853 - accuracy: 0.3216 - val_loss: 2.1302 - val_accuracy: 0.3406
# Epoch 12/50
# 30/30 [==============================] - 0s 11ms/step - loss: 2.0806 - accuracy: 0.3719 - val_loss: 2.1518 - val_accuracy: 0.3375
# Epoch 13/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.1383 - accuracy: 0.3419 - val_loss: 2.0732 - val_accuracy: 0.3484
# Epoch 14/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.0003 - accuracy: 0.3798 - val_loss: 2.0944 - val_accuracy: 0.3391
# Epoch 15/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.1007 - accuracy: 0.3461 - val_loss: 2.0369 - val_accuracy: 0.3828
# Epoch 16/50
# 30/30 [==============================] - 0s 11ms/step - loss: 2.0079 - accuracy: 0.3850 - val_loss: 1.9716 - val_accuracy: 0.3875
# Epoch 17/50
# 30/30 [==============================] - 0s 11ms/step - loss: 1.9465 - accuracy: 0.4083 - val_loss: 1.9384 - val_accuracy: 0.3969
# Epoch 18/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.9153 - accuracy: 0.4033 - val_loss: 1.9590 - val_accuracy: 0.3984
# Epoch 19/50
# 30/30 [==============================] - 0s 11ms/step - loss: 1.8388 - accuracy: 0.4322 - val_loss: 1.8769 - val_accuracy: 0.4156
# Epoch 20/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.8371 - accuracy: 0.4429 - val_loss: 1.8899 - val_accuracy: 0.4344
# Epoch 21/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.7913 - accuracy: 0.4456 - val_loss: 1.9255 - val_accuracy: 0.4062
# Epoch 22/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.7870 - accuracy: 0.4413 - val_loss: 1.8505 - val_accuracy: 0.4281
# Epoch 23/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.7877 - accuracy: 0.4453 - val_loss: 1.8958 - val_accuracy: 0.4094
# Epoch 24/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.7806 - accuracy: 0.4376 - val_loss: 1.8061 - val_accuracy: 0.4500
# Epoch 25/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.7786 - accuracy: 0.4512 - val_loss: 1.8532 - val_accuracy: 0.4281
# Epoch 26/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.7431 - accuracy: 0.4591 - val_loss: 1.7737 - val_accuracy: 0.4250
# Epoch 27/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.6965 - accuracy: 0.4721 - val_loss: 1.7119 - val_accuracy: 0.4688
# Epoch 28/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.6449 - accuracy: 0.4948 - val_loss: 1.8080 - val_accuracy: 0.4375
# Epoch 29/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.6999 - accuracy: 0.4750 - val_loss: 1.7523 - val_accuracy: 0.4500
# Epoch 30/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.6609 - accuracy: 0.4784 - val_loss: 1.7112 - val_accuracy: 0.5016
# Epoch 31/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.6521 - accuracy: 0.4892 - val_loss: 1.8663 - val_accuracy: 0.4094
# Epoch 32/50
# 30/30 [==============================] - 0s 11ms/step - loss: 1.5762 - accuracy: 0.5091 - val_loss: 1.6821 - val_accuracy: 0.4719
# Epoch 33/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.6510 - accuracy: 0.4889 - val_loss: 1.6300 - val_accuracy: 0.4906
# Epoch 34/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.5450 - accuracy: 0.5012 - val_loss: 1.7325 - val_accuracy: 0.4625
# Epoch 35/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.6229 - accuracy: 0.4869 - val_loss: 1.7180 - val_accuracy: 0.4656
# Epoch 36/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.5819 - accuracy: 0.5078 - val_loss: 1.7704 - val_accuracy: 0.4484
# Epoch 37/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.5297 - accuracy: 0.5087 - val_loss: 1.7569 - val_accuracy: 0.4531
# Epoch 38/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.5421 - accuracy: 0.5084 - val_loss: 1.6609 - val_accuracy: 0.4797
# Epoch 39/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.5463 - accuracy: 0.5126 - val_loss: 1.7217 - val_accuracy: 0.4859
# Epoch 40/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.5531 - accuracy: 0.5157 - val_loss: 1.6671 - val_accuracy: 0.4812
# Epoch 41/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.4962 - accuracy: 0.5266 - val_loss: 1.8307 - val_accuracy: 0.4422
# Epoch 42/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.4838 - accuracy: 0.5297 - val_loss: 1.6856 - val_accuracy: 0.4844
# Epoch 43/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.4717 - accuracy: 0.5393 - val_loss: 1.5791 - val_accuracy: 0.5328
# Epoch 44/50
# 30/30 [==============================] - 0s 11ms/step - loss: 1.4852 - accuracy: 0.5316 - val_loss: 1.6833 - val_accuracy: 0.4781
# Epoch 45/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.5336 - accuracy: 0.5143 - val_loss: 1.7067 - val_accuracy: 0.4766
# Epoch 46/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.4502 - accuracy: 0.5361 - val_loss: 1.6835 - val_accuracy: 0.4984
# Epoch 47/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.4958 - accuracy: 0.5213 - val_loss: 1.5523 - val_accuracy: 0.5297
# Epoch 48/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.3758 - accuracy: 0.5690 - val_loss: 1.6709 - val_accuracy: 0.4891
# Epoch 49/50
# 30/30 [==============================] - 0s 11ms/step - loss: 1.5037 - accuracy: 0.5247 - val_loss: 1.5594 - val_accuracy: 0.5312
# Epoch 50/50
# 30/30 [==============================] - 0s 10ms/step - loss: 1.3473 - accuracy: 0.5716 - val_loss: 1.7131 - val_accuracy: 0.4828
# Test set evaluation metrics
# 30/30 [==============================] - 0s 4ms/step - loss: 1.6202 - accuracy: 0.5096
# loss: 1.62
# accuracy: 0.51

# %% [markdown]
# ### Μεταφορά μάθησης: VGG16

# %%
# transfer learning: VGG16 trained on ImageNet without the top layer

def init_VGG16_model(summary):
  VGG16_MODEL=tf.keras.applications.VGG16(input_shape=(img_rows, img_cols, img_channels), include_top=False, weights='imagenet')
  
  VGG16_MODEL.trainable=True
  fine_tune_at = 2*len(VGG16_MODEL.layers)//3
  for layer in VGG16_MODEL.layers[:fine_tune_at]:
    layer.trainable =  False
  
#we tried all three for all models, this is how, only the last implementation can be seen on the below models

  dropout_layer = tf.keras.layers.Dropout(rate = 0.5)
  global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

  # add top layer for CIFAR100 classification
  prediction_layer = tf.keras.layers.Dense(len(CIFAR100_LABELS_LIST),activation='softmax')
  model = tf.keras.Sequential([VGG16_MODEL, dropout_layer, global_average_layer, prediction_layer])
  model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.00005), loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=["accuracy"])
  if summary: 
    model.summary()
  return model

# %%
VGG16_MODEL = init_VGG16_model(True)
start = time.time()
VGG16_MODEL_history = train_model(VGG16_MODEL, 25, 40, 10)
end = time.time()
print("Time elapsed:")
print(end - start)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 1, 1, 512)         14714688
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 1, 512)         0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               51300
# =================================================================
# Total params: 14,765,988
# Trainable params: 11,850,340
# Non-trainable params: 2,915,648
# _________________________________________________________________
# Epoch 1/25
# 40/40 [==============================] - 3s 49ms/step - loss: 4.1604 - accuracy: 0.0719 - val_loss: 2.3496 - val_accuracy: 0.3320
# Epoch 2/25
# 40/40 [==============================] - 2s 42ms/step - loss: 2.5962 - accuracy: 0.2983 - val_loss: 1.8660 - val_accuracy: 0.4555
# Epoch 3/25
# 40/40 [==============================] - 2s 42ms/step - loss: 2.0917 - accuracy: 0.4098 - val_loss: 1.6702 - val_accuracy: 0.5008
# Epoch 4/25
# 40/40 [==============================] - 2s 41ms/step - loss: 1.8178 - accuracy: 0.4673 - val_loss: 1.4970 - val_accuracy: 0.5437
# Epoch 5/25
# 40/40 [==============================] - 2s 42ms/step - loss: 1.6163 - accuracy: 0.5291 - val_loss: 1.4805 - val_accuracy: 0.5500
# Epoch 6/25
# 40/40 [==============================] - 2s 42ms/step - loss: 1.4068 - accuracy: 0.5798 - val_loss: 1.3816 - val_accuracy: 0.5820
# Epoch 7/25
# 40/40 [==============================] - 2s 42ms/step - loss: 1.3171 - accuracy: 0.6165 - val_loss: 1.2961 - val_accuracy: 0.6008
# Epoch 8/25
# 40/40 [==============================] - 2s 42ms/step - loss: 1.1582 - accuracy: 0.6572 - val_loss: 1.3320 - val_accuracy: 0.5922
# Epoch 9/25
# 40/40 [==============================] - 2s 42ms/step - loss: 1.1485 - accuracy: 0.6488 - val_loss: 1.2942 - val_accuracy: 0.6102
# Epoch 10/25
# 40/40 [==============================] - 2s 42ms/step - loss: 1.0150 - accuracy: 0.6932 - val_loss: 1.2498 - val_accuracy: 0.6242
# Epoch 11/25
# 40/40 [==============================] - 2s 41ms/step - loss: 0.8612 - accuracy: 0.7367 - val_loss: 1.2652 - val_accuracy: 0.6156
# Epoch 12/25
# 40/40 [==============================] - 2s 41ms/step - loss: 0.8419 - accuracy: 0.7378 - val_loss: 1.2237 - val_accuracy: 0.6195
# Epoch 13/25
# 40/40 [==============================] - 2s 41ms/step - loss: 0.7549 - accuracy: 0.7643 - val_loss: 1.2676 - val_accuracy: 0.6250
# Epoch 14/25
# 40/40 [==============================] - 2s 41ms/step - loss: 0.6533 - accuracy: 0.7976 - val_loss: 1.2740 - val_accuracy: 0.6156
# Epoch 15/25
# 40/40 [==============================] - 2s 41ms/step - loss: 0.6386 - accuracy: 0.7932 - val_loss: 1.2770 - val_accuracy: 0.6313
# Epoch 16/25
# 40/40 [==============================] - 2s 41ms/step - loss: 0.4914 - accuracy: 0.8514 - val_loss: 1.2924 - val_accuracy: 0.6258
# Epoch 17/25
# 40/40 [==============================] - 2s 40ms/step - loss: 0.4896 - accuracy: 0.8438 - val_loss: 1.3189 - val_accuracy: 0.6461
# Epoch 18/25
# 40/40 [==============================] - 2s 41ms/step - loss: 0.3699 - accuracy: 0.8881 - val_loss: 1.3320 - val_accuracy: 0.6359
# Epoch 19/25
# 40/40 [==============================] - 2s 41ms/step - loss: 0.3667 - accuracy: 0.8868 - val_loss: 1.3360 - val_accuracy: 0.6500
# Epoch 20/25
# 40/40 [==============================] - 2s 40ms/step - loss: 0.2939 - accuracy: 0.9096 - val_loss: 1.4248 - val_accuracy: 0.6266
# Epoch 21/25
# 40/40 [==============================] - 2s 40ms/step - loss: 0.2221 - accuracy: 0.9374 - val_loss: 1.4899 - val_accuracy: 0.6109
# Epoch 22/25
# 40/40 [==============================] - 2s 40ms/step - loss: 0.2344 - accuracy: 0.9253 - val_loss: 1.4317 - val_accuracy: 0.6508
# Time elapsed:
# 61.15541863441467

# %%
model_report(VGG16_MODEL, VGG16_MODEL_history, 30)
# Out:
# Test set evaluation metrics
# 30/30 [==============================] - 1s 18ms/step - loss: 1.4169 - accuracy: 0.6672
# loss: 1.42
# accuracy: 0.67

# %% [markdown]
# # Βελτίωση της επίδοσης με πειράματα
#
# Καλείστε να βελτιώσετε τα αποτελέσματα ταξινόμησης στο CIFAR-100 και να βγάλατε συμπεράσματα, σύμφωνα με όσα ζητούνται σε σχέση με την αναφορά παράδοσης.

# %% [markdown]
# ## Δοκιμές διαφορετικών μοντέλων
#
# Μπορείτε είτε να δοκιμάσετε μοντέλα "from scratch", όπου ορίζετε την αρχιτεκτονική του δικτύου όπως θέλετε, είτε να χρησιμοποιήσετε μεταφορά μάθησης.

# %% [markdown]
# ### Μοντέλα "from scratch"
#
# Μπορείτε να τροποποιήσετε/αλλάξετε το αρχικό μικρό συνελικτικό δίκτυο του παραδείγματος. Μπορείτε να συμβουλευτείτε
# - τη [βιβλιογραφία απο το leaderboard του CIFAR-100](https://benchmarks.ai/cifar-100) για αρχιτεκτονικές και παραμέτρους των δικτύων
# - ή/και να πάρετε ιδέες [από σχετική αναζήτηση στο Google Scholar](https://scholar.google.gr/scholar?hl=en&as_sdt=0%2C5&q=cifar+100+cnn&oq=cifa)

# %%
def init_our_model(summary):
    model = models.Sequential()

    model.add(layers.Conv2D(32, (2, 2), input_shape=(32, 32, 3)))
    model.add(layers.Conv2D(64, (2, 2)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.3))
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.2))

    model.add(layers.Conv2D(128, (2, 2)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.3))
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.2))

    model.add(layers.Conv2D(256, (3, 3)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.3))
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(1024))
    model.add(layers.LeakyReLU(alpha=0.3))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(100, activation='softmax'))

    optimizer = tf.optimizers.Adam(learning_rate=0.0001)
    lossf = tf.keras.losses.sparse_categorical_crossentropy

    model.compile(optimizer=optimizer, loss=lossf, metrics=["accuracy"])
    if summary: model.summary()
    return model

# %%
model = init_our_model(summary = True)
model_history = train_model(model, 100, 30, 5)
model_report(model, model_history, 30)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 31, 31, 32)        416
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 30, 30, 64)        8256
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 30, 30, 64)        256
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 30, 30, 64)        0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 15, 15, 64)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 14, 14, 128)       32896
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 5, 5, 256)         295168
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 5, 5, 256)         1024
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 5, 5, 256)         0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 1024)              0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 100)               102500
# =================================================================
# Total params: 1,490,628
# Trainable params: 1,489,732
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/100
# 30/30 [==============================] - 2s 32ms/step - loss: 4.9399 - accuracy: 0.0497 - val_loss: 4.2898 - val_accuracy: 0.0656
# Epoch 2/100
# 30/30 [==============================] - 1s 20ms/step - loss: 3.3479 - accuracy: 0.1442 - val_loss: 4.0111 - val_accuracy: 0.0562
# Epoch 3/100
# 30/30 [==============================] - 1s 20ms/step - loss: 3.0670 - accuracy: 0.1650 - val_loss: 3.7899 - val_accuracy: 0.1016
# Epoch 4/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.8032 - accuracy: 0.2114 - val_loss: 3.6813 - val_accuracy: 0.0875
# Epoch 5/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.7697 - accuracy: 0.2168 - val_loss: 3.6246 - val_accuracy: 0.0828
# Epoch 6/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.6592 - accuracy: 0.2388 - val_loss: 3.5072 - val_accuracy: 0.0891
# Epoch 7/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.5986 - accuracy: 0.2573 - val_loss: 3.5179 - val_accuracy: 0.0906
# Epoch 8/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.5652 - accuracy: 0.2415 - val_loss: 3.6075 - val_accuracy: 0.0938
# Epoch 9/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.4879 - accuracy: 0.2648 - val_loss: 3.4946 - val_accuracy: 0.0859
# Epoch 10/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.4232 - accuracy: 0.2808 - val_loss: 3.3701 - val_accuracy: 0.0938
# Epoch 11/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.3989 - accuracy: 0.2866 - val_loss: 3.2310 - val_accuracy: 0.1141
# Epoch 12/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.3794 - accuracy: 0.2773 - val_loss: 3.1584 - val_accuracy: 0.1203
# Epoch 13/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.2673 - accuracy: 0.3166 - val_loss: 3.0867 - val_accuracy: 0.1219
# Epoch 14/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.2680 - accuracy: 0.3113 - val_loss: 2.9246 - val_accuracy: 0.1406
# Epoch 15/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.2785 - accuracy: 0.3239 - val_loss: 2.7974 - val_accuracy: 0.1594
# Epoch 16/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.2021 - accuracy: 0.3424 - val_loss: 2.7107 - val_accuracy: 0.1703
# Epoch 17/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.1871 - accuracy: 0.3290 - val_loss: 2.5606 - val_accuracy: 0.2172
# Epoch 18/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.1953 - accuracy: 0.3291 - val_loss: 2.3743 - val_accuracy: 0.2797
# Epoch 19/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.1035 - accuracy: 0.3644 - val_loss: 2.3404 - val_accuracy: 0.2797
# Epoch 20/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.1428 - accuracy: 0.3533 - val_loss: 2.2622 - val_accuracy: 0.3156
# Epoch 21/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.1391 - accuracy: 0.3588 - val_loss: 2.1339 - val_accuracy: 0.3250
# Epoch 22/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.0884 - accuracy: 0.3669 - val_loss: 2.1823 - val_accuracy: 0.3375
# Epoch 23/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.0942 - accuracy: 0.3618 - val_loss: 2.0170 - val_accuracy: 0.3719
# Epoch 24/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.0315 - accuracy: 0.3778 - val_loss: 2.0651 - val_accuracy: 0.3469
# Epoch 25/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.1054 - accuracy: 0.3740 - val_loss: 2.0059 - val_accuracy: 0.3500
# Epoch 26/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.0547 - accuracy: 0.3682 - val_loss: 2.0721 - val_accuracy: 0.3406
# Epoch 27/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.0197 - accuracy: 0.3959 - val_loss: 2.1079 - val_accuracy: 0.3297
# Epoch 28/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.9730 - accuracy: 0.4064 - val_loss: 1.9269 - val_accuracy: 0.3969
# Epoch 29/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.9917 - accuracy: 0.3911 - val_loss: 1.9186 - val_accuracy: 0.3938
# Epoch 30/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.9227 - accuracy: 0.4015 - val_loss: 2.0396 - val_accuracy: 0.3531
# Epoch 31/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.9301 - accuracy: 0.3982 - val_loss: 1.8776 - val_accuracy: 0.4062
# Epoch 32/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.8904 - accuracy: 0.4179 - val_loss: 1.8704 - val_accuracy: 0.3984
# Epoch 33/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.9647 - accuracy: 0.4056 - val_loss: 1.9444 - val_accuracy: 0.4031
# Epoch 34/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.9146 - accuracy: 0.4205 - val_loss: 1.9410 - val_accuracy: 0.3906
# Epoch 35/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.8771 - accuracy: 0.4287 - val_loss: 1.9824 - val_accuracy: 0.3781
# Epoch 36/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.8746 - accuracy: 0.4094 - val_loss: 1.9213 - val_accuracy: 0.4000
# Epoch 37/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.8929 - accuracy: 0.4297 - val_loss: 1.9315 - val_accuracy: 0.3938
# Epoch 38/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.8555 - accuracy: 0.4195 - val_loss: 1.7839 - val_accuracy: 0.4656
# Epoch 39/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.8307 - accuracy: 0.4436 - val_loss: 1.9113 - val_accuracy: 0.4047
# Epoch 40/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.8098 - accuracy: 0.4559 - val_loss: 1.8863 - val_accuracy: 0.3953
# Epoch 41/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.8193 - accuracy: 0.4391 - val_loss: 1.8192 - val_accuracy: 0.4250
# Epoch 42/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.8283 - accuracy: 0.4431 - val_loss: 1.8489 - val_accuracy: 0.4172
# Epoch 43/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.7945 - accuracy: 0.4651 - val_loss: 1.8624 - val_accuracy: 0.4094
# Epoch 44/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.7483 - accuracy: 0.4550 - val_loss: 1.7365 - val_accuracy: 0.4516
# Epoch 45/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.8046 - accuracy: 0.4597 - val_loss: 1.8414 - val_accuracy: 0.4359
# Epoch 46/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.7736 - accuracy: 0.4551 - val_loss: 1.8911 - val_accuracy: 0.4219
# Epoch 47/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.7929 - accuracy: 0.4591 - val_loss: 1.7836 - val_accuracy: 0.4422
# Epoch 48/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.7371 - accuracy: 0.4674 - val_loss: 1.9372 - val_accuracy: 0.3844
# Epoch 49/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.7419 - accuracy: 0.4580 - val_loss: 1.8825 - val_accuracy: 0.4281
# Epoch 50/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.7037 - accuracy: 0.4701 - val_loss: 1.9330 - val_accuracy: 0.3953
# Epoch 51/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.7249 - accuracy: 0.4824 - val_loss: 2.0777 - val_accuracy: 0.3609
# Epoch 52/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.6834 - accuracy: 0.4870 - val_loss: 1.8135 - val_accuracy: 0.4391
# Epoch 53/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.6481 - accuracy: 0.4923 - val_loss: 1.8318 - val_accuracy: 0.4391
# Epoch 54/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.7259 - accuracy: 0.4590 - val_loss: 1.7440 - val_accuracy: 0.4375
# Test set evaluation metrics
# 30/30 [==============================] - 0s 7ms/step - loss: 1.6859 - accuracy: 0.4693
# loss: 1.69
# accuracy: 0.47

# %% [markdown]
# ### Μεταφορά μάθησης
#
# Εναλλακτικά, μπορείτε να χρησιμοποιήσετ τη [μεταφορά μάθησης του tf2](https://www.tensorflow.org/tutorials/images/transfer_learning). Σε αντίθεση με τα μοντέλα "from scratch" η μεταφορά μάθησης μας επιστρέφει έτοιμα μοντέλα με προκαθορισμένη αρχιτεκτονική στην οποία μπορούμε γενικά μόνο να προσθέσουμε επίπεδα, τα οποία συνήθως περιορίζοντα σε πλήρως διασυνδεδεμένα επίπεδα που εξειδικεύονται στο συγκεκριμένο task ταξινόμησης που έχουμε να επιτελέσουμε.

# %% [markdown]
# #### Εκπαίδευση βαρών
#
# Ταυτόχρονα με την αρχιτεκτονική, στη μεταφορά μάθησης εισάγουμε και τη γνώση που έχει αποκτήσει το μοντέλο, δηλαδή τις τιμές των βαρών του όπως έχουν προκύψει μετά από εκπαίδευση συνήθως στο (τεράστιο) ImageNet. Οταν εισάγουμε ένα μοντέλο με μεταφορά μάθησης έχουμε τρεις επιλογές για την εκπαίδευση:
# - να παγώσουμε τη συνελικτική βάση και να εκπαιδεύσουμε την κεφαλή ταξινόμησης (classification head). Αυτό αντιστοιχεί στο να χρησιμοποιήσουμε τη συνελικτική βάση για εξαγωγή χαρακτηριστικών (feature extraction), σημαία trainable = False.
# - να συνεχίσουμε να εκπαιδεύουμε όλα τα επίπεδα του δικτύου, σημαία trainable = True.
# - να εκπαιδευτεί μόνο ένα ποσοστό των επιπέδων, εβρισκόμενο προς την έξοδο του δικτύου. Οι σημαίες trainable εδώ θα πρέπει να οριστούν ανά επίπεδο.

# %% [markdown]
# #### Διαθέσιμα μοντέλα για μεταφορά μάθησης στο tf2
#
# 1. tf.keras.applications. Ο πιο απλός τρόπος για να κάνουμε μεταφορά μάθησης στο tf2 είναι μέσω του [tf.keras.applications](https://www.tensorflow.org/api_docs/python/tf/keras/applications) που παρέχει προεκπαιδευμένα μοντέλα από το Keras και συγκεκριμένα τα δίκτυα: DenseNet, Inception-ResNet V2, Inception V3, MobileNet v1, MobileNet v2, NASNet-A, ResNet, ResNet v2, VGG16, VGG19 και Xception V1. Η εισαγωγή των μοντέλων γίνεται παρόμοια με αυτή που δείξαμε παραπάνω για το VGG16.
#
# 2. TensorFlow Hub. Μπορείτε επίσης να χρησιμοποιήσετε μοντέλα τα οποία είναι διαθέσιμα στο αποθετήριο [TensoFlow Hub](https://tfhub.dev/s?fine-tunable=yes&module-type=image-augmentation,image-classification,image-feature-vector,image-generator,image-object-detection,image-others,image-style-transfer,image-rnn-agent&tf-version=tf2) το οποίο περιλαμβάνει πάνω από 100 προεκπαιδευμένα μοντέλα.
#
# 3. Αποθηκευμένα μοντέλα απο τρίτες πηγές. Μπορείτε επίσης να κάνετε μεταφορά μάθησης από τρίτες πηγές, είτε του συνόλου του νευρωνικού, αρχιτεκτονικής και βαρών, είτε μόνο της αρχιτεκτονικής ή των βαρών. Το μοντέλο θα πρέπει να έχει αποθηκευθεί σε ένα από τα δύο φορμάτ, Keras HDF5 format (.h5 ή .keras) ή στο SavedModel format που αναφέραμε στην εισαγωγή. Τα βάρη μπορούν να εισαχθούν και μόνα τους ως Checkpoints. Για περισσότερα, διαβάστε σχετικά τα λήμματα ["Save and load models"](https://www.tensorflow.org/tutorials/keras/save_and_load), ["Save and serialize"](https://www.tensorflow.org/guide/keras/save_and_serialize), ["Using the SavedModel format"](https://www.tensorflow.org/guide/saved_model) και δείτε για παράδειγμα πως μπορούμε να κάνουμε μεταφορά μάθησης από τα state-of-the-art EfficientNets ([1](https://www.dlology.com/blog/transfer-learning-with-efficientnet/), [2](https://github.com/tensorflow/tpu/tree/master/models/official/efficientnethttps://)).
#
# Σημειώστε ότι πολλά μοντέλα απαιτούν μεγαλύτερες διαστάσεις στην είσοδο από αυτές του CIFAR-100 και κατά συνέπεια τα δεδομένα πρέπει να [μετασχηματιστούν](https://www.tensorflow.org/api_docs/python/tf/image/resize). Προσέξτε ωστόσο τις απαιτήσεις σε μνήμη όταν αυτοί οι μετασχηματισμοί γίνονται απευθείας σε μεταβλητές (βλ. πιο κάτω "Διαχείριση μνήμης").

# %% [markdown]
# ### Επαύξηση δεδομένων
#
# Μια τεχνική που μπορεί να σας δώσει καλά αποτελέσματα είναι η επάυξηση δεδομένων (data augmentation). Η επαύξηση δεδομένων επιτρέπει να δημιουργήσουμε μεγαλύτερη ποικιλία στα δεδομένα εφαρμόζοντας τυχαίους αλλά ρεαλιστικούς μετασχηματισμούς στις εικόνες, όπως πχ η περιστροφη.
#
# Μπορούμε να κάνουμε data augmetation με δύο τρόπους: με επίπεδα προεπεξεργασίας του Keras, ή με χρήση του tf.image. Δείτε [εδώ](https://www.tensorflow.org/tutorials/images/data_augmentation) σχετικά από το documentation του TensorFlow και [εδώ](https://stepup.ai/train_data_augmentation_keras/) ένα πρακτικό παράδειγμα στο CIFAR-10.

# %% [markdown]
# ### ResNet

# %%
def init_resnet_model(summary):
    resnet_MODEL = tf.keras.applications.resnet.ResNet50(input_shape=(img_rows, img_cols, img_channels),include_top=False, weights='imagenet')
                          
    # unfreeze conv layers
    resnet_MODEL.trainable = True
    dropout_layer = tf.keras.layers.Dropout(rate=0.7)
    dropout_layer.trainable = True
    global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
    global_average_layer.trainable = True
    
    # add top layer for CIFAR100 classification
    prediction_layer = tf.keras.layers.Dense(len(CIFAR100_LABELS_LIST),activation='softmax')
    model = tf.keras.Sequential([resnet_MODEL, dropout_layer, global_average_layer, prediction_layer])
    model.compile(optimizer=tf.optimizers.RMSprop(learning_rate=0.0001),loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=["accuracy"])

    if summary: model.summary()
    return model

resnet_MODEL = init_resnet_model(summary = True)
resnet_MODEL_history = train_model(resnet_MODEL, 50, 40, 10) # re-train for less epochs
model_report(resnet_MODEL, resnet_MODEL_history, 30)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 1, 1, 2048)        23587712
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 1, 1, 2048)        0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 2048)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 100)               204900
# =================================================================
# Total params: 23,792,612
# Trainable params: 23,739,492
# Non-trainable params: 53,120
# _________________________________________________________________
# Epoch 1/50
# 40/40 [==============================] - 15s 138ms/step - loss: 7.2677 - accuracy: 0.0177 - val_loss: 52.5397 - val_accuracy: 0.0531
# Epoch 2/50
# 40/40 [==============================] - 4s 89ms/step - loss: 4.7059 - accuracy: 0.0806 - val_loss: 23.9535 - val_accuracy: 0.0437
# Epoch 3/50
# 40/40 [==============================] - 4s 90ms/step - loss: 3.9536 - accuracy: 0.1600 - val_loss: 30.2763 - val_accuracy: 0.0516
# Epoch 4/50
# 40/40 [==============================] - 4s 90ms/step - loss: 3.2528 - accuracy: 0.2581 - val_loss: 42.0383 - val_accuracy: 0.0555
# Epoch 5/50
# 40/40 [==============================] - 4s 90ms/step - loss: 2.5943 - accuracy: 0.3549 - val_loss: 40.2595 - val_accuracy: 0.0492
# Epoch 6/50
# 40/40 [==============================] - 4s 89ms/step - loss: 2.0207 - accuracy: 0.4611 - val_loss: 8.8834 - val_accuracy: 0.0484
# Epoch 7/50
# 40/40 [==============================] - 4s 88ms/step - loss: 1.8806 - accuracy: 0.4938 - val_loss: 6.8519 - val_accuracy: 0.0523
# Epoch 8/50
# 40/40 [==============================] - 3s 86ms/step - loss: 1.5112 - accuracy: 0.5735 - val_loss: 16.2211 - val_accuracy: 0.0477
# Epoch 9/50
# 40/40 [==============================] - 4s 87ms/step - loss: 1.3342 - accuracy: 0.6272 - val_loss: 19.1585 - val_accuracy: 0.0547
# Epoch 10/50
# 40/40 [==============================] - 4s 87ms/step - loss: 1.1903 - accuracy: 0.6464 - val_loss: 8.9273 - val_accuracy: 0.0516
# Epoch 11/50
# 40/40 [==============================] - 3s 86ms/step - loss: 0.8648 - accuracy: 0.7410 - val_loss: 6.6254 - val_accuracy: 0.0508
# Epoch 12/50
# 40/40 [==============================] - 3s 86ms/step - loss: 0.8773 - accuracy: 0.7345 - val_loss: 12.6459 - val_accuracy: 0.0508
# Epoch 13/50
# 40/40 [==============================] - 3s 86ms/step - loss: 0.6858 - accuracy: 0.7971 - val_loss: 6.0660 - val_accuracy: 0.0531
# Epoch 14/50
# 40/40 [==============================] - 3s 86ms/step - loss: 0.6228 - accuracy: 0.8172 - val_loss: 4.0939 - val_accuracy: 0.0375
# Epoch 15/50
# 40/40 [==============================] - 3s 86ms/step - loss: 0.4862 - accuracy: 0.8520 - val_loss: 4.8560 - val_accuracy: 0.0594
# Epoch 16/50
# 40/40 [==============================] - 4s 88ms/step - loss: 0.3659 - accuracy: 0.8933 - val_loss: 6.1101 - val_accuracy: 0.0633
# Epoch 17/50
# 40/40 [==============================] - 4s 88ms/step - loss: 0.3745 - accuracy: 0.8790 - val_loss: 5.9078 - val_accuracy: 0.0672
# Epoch 18/50
# 40/40 [==============================] - 4s 88ms/step - loss: 0.2554 - accuracy: 0.9209 - val_loss: 4.7325 - val_accuracy: 0.1070
# Epoch 19/50
# 40/40 [==============================] - 3s 87ms/step - loss: 0.2729 - accuracy: 0.9203 - val_loss: 5.0187 - val_accuracy: 0.1320
# Epoch 20/50
# 40/40 [==============================] - 4s 87ms/step - loss: 0.2296 - accuracy: 0.9300 - val_loss: 4.7745 - val_accuracy: 0.1867
# Epoch 21/50
# 40/40 [==============================] - 4s 87ms/step - loss: 0.1817 - accuracy: 0.9436 - val_loss: 4.8159 - val_accuracy: 0.2469
# Epoch 22/50
# 40/40 [==============================] - 4s 87ms/step - loss: 0.1977 - accuracy: 0.9412 - val_loss: 5.0932 - val_accuracy: 0.3406
# Epoch 23/50
# 40/40 [==============================] - 4s 87ms/step - loss: 0.1723 - accuracy: 0.9481 - val_loss: 4.6139 - val_accuracy: 0.3961
# Epoch 24/50
# 40/40 [==============================] - 3s 86ms/step - loss: 0.1726 - accuracy: 0.9481 - val_loss: 4.1667 - val_accuracy: 0.4547
# Test set evaluation metrics
# 30/30 [==============================] - 1s 21ms/step - loss: 4.2159 - accuracy: 0.4414
# loss: 4.22
# accuracy: 0.44

# %% [markdown]
# ### DesNet

# %%
def init_densenet_model(summary):
    densenet_MODEL=tf.keras.applications.densenet.DenseNet121(input_shape=(img_rows, img_cols, img_channels),
                                                              include_top=False,
                                                              weights='imagenet')
    # unfreeze conv layers
    densenet_MODEL.trainable = True
    dropout_layer = tf.keras.layers.Dropout(rate=0.5)
    dropout_layer.trainable = True
    global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
    global_average_layer.trainable = True
    
    # add top layer for CIFAR100 classification
    prediction_layer = tf.keras.layers.Dense(len(CIFAR100_LABELS_LIST),activation='softmax')
    model = tf.keras.Sequential([densenet_MODEL, dropout_layer, global_average_layer, prediction_layer])

    model.compile(optimizer=tf.optimizers.RMSprop(learning_rate=0.0001),
                  loss=tf.keras.losses.sparse_categorical_crossentropy,
                  metrics=["accuracy"])
    if summary: model.summary()
    return model

densenet_MODEL = init_densenet_model(summary = True)
densenet_MODEL_history = train_model(densenet_MODEL, 20, 40, 10) # re-train for less epochs
model_report(densenet_MODEL, densenet_MODEL_history, 30)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Functional)     (None, 1, 1, 1024)        7037504
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 1, 1, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 1024)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 100)               102500
# =================================================================
# Total params: 7,140,004
# Trainable params: 7,056,356
# Non-trainable params: 83,648
# _________________________________________________________________
# Epoch 1/20
# 40/40 [==============================] - 24s 170ms/step - loss: 5.0221 - accuracy: 0.0526 - val_loss: 3.8522 - val_accuracy: 0.1320
# Epoch 2/20
# 40/40 [==============================] - 3s 80ms/step - loss: 3.0188 - accuracy: 0.2204 - val_loss: 3.2800 - val_accuracy: 0.2523
# Epoch 3/20
# 40/40 [==============================] - 3s 80ms/step - loss: 2.1893 - accuracy: 0.3707 - val_loss: 2.7990 - val_accuracy: 0.3359
# Epoch 4/20
# 40/40 [==============================] - 3s 80ms/step - loss: 1.7547 - accuracy: 0.4893 - val_loss: 2.3318 - val_accuracy: 0.4359
# Epoch 5/20
# 40/40 [==============================] - 3s 79ms/step - loss: 1.4428 - accuracy: 0.5587 - val_loss: 1.9747 - val_accuracy: 0.5016
# Epoch 6/20
# 40/40 [==============================] - 3s 80ms/step - loss: 1.1134 - accuracy: 0.6517 - val_loss: 1.7353 - val_accuracy: 0.5352
# Epoch 7/20
# 40/40 [==============================] - 3s 80ms/step - loss: 1.0139 - accuracy: 0.6930 - val_loss: 1.4917 - val_accuracy: 0.5891
# Epoch 8/20
# 40/40 [==============================] - 3s 80ms/step - loss: 0.7896 - accuracy: 0.7699 - val_loss: 1.4103 - val_accuracy: 0.5813
# Epoch 9/20
# 40/40 [==============================] - 3s 78ms/step - loss: 0.6690 - accuracy: 0.7912 - val_loss: 1.3050 - val_accuracy: 0.6055
# Epoch 10/20
# 40/40 [==============================] - 3s 77ms/step - loss: 0.5148 - accuracy: 0.8479 - val_loss: 1.2898 - val_accuracy: 0.6141
# Epoch 11/20
# 40/40 [==============================] - 3s 78ms/step - loss: 0.3695 - accuracy: 0.8946 - val_loss: 1.2462 - val_accuracy: 0.6211
# Epoch 12/20
# 40/40 [==============================] - 3s 78ms/step - loss: 0.3821 - accuracy: 0.8911 - val_loss: 1.2870 - val_accuracy: 0.6289
# Epoch 13/20
# 40/40 [==============================] - 3s 78ms/step - loss: 0.2439 - accuracy: 0.9338 - val_loss: 1.2605 - val_accuracy: 0.6398
# Epoch 14/20
# 40/40 [==============================] - 3s 79ms/step - loss: 0.2419 - accuracy: 0.9343 - val_loss: 1.2959 - val_accuracy: 0.6523
# Epoch 15/20
# 40/40 [==============================] - 3s 78ms/step - loss: 0.1890 - accuracy: 0.9460 - val_loss: 1.3408 - val_accuracy: 0.6391
# Epoch 16/20
# 40/40 [==============================] - 3s 78ms/step - loss: 0.1152 - accuracy: 0.9673 - val_loss: 1.3466 - val_accuracy: 0.6383
# Epoch 17/20
# 40/40 [==============================] - 3s 78ms/step - loss: 0.1355 - accuracy: 0.9624 - val_loss: 1.3441 - val_accuracy: 0.6484
# Epoch 18/20
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0859 - accuracy: 0.9752 - val_loss: 1.3925 - val_accuracy: 0.6570
# Epoch 19/20
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0852 - accuracy: 0.9779 - val_loss: 1.4606 - val_accuracy: 0.6438
# Epoch 20/20
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0783 - accuracy: 0.9777 - val_loss: 1.4347 - val_accuracy: 0.6570
# Test set evaluation metrics
# 30/30 [==============================] - 1s 18ms/step - loss: 1.3623 - accuracy: 0.6672
# loss: 1.36
# accuracy: 0.67

# %% [markdown]
# ## Παρατηρήσεις ως προς τη βελτιστοποίηση

# %% [markdown]
# ### Διαχείριση μνήμης (TFRecord)
#
# Η φόρτωση δεδομένων με τον τρόπο που το κάναμε παραπάνω στο απλό παράδειγμα υλοποίησης είναι πολύ βολική αλλά δεν είναι καθόλου αποτελεσματική ως προς τη διαχείριση της μνήμης. Συγκεκριμένα, με τον τρόπο αυτό, τα δεδομένα αποθηκεύονται απευθείας σε μεταβλητές, οι οποίες όλες μαζί καταλαμβάνουν τη RAM της CPU ή της GPU, κάτι που κάνει αδύνατη τη διαχείριση μεγάλων datasets ή τον μεταχηματισμό των δεδομένων όπως όταν κάνουμε αύξηση δεδομένων (data augmentation).
#
# Για να παρακαμφθεί αυτό το πρόβλημα, υπάρχει η δυνατότητα της σειριοποίησης των δεδομένων (serialization) και της αποθήκευσής τους σε αρχεία μεσαίου μεγέθους (κάποιων MB) τα οποία μπορούνα να αναγνωστούν γραμμικά. Το φορμάτ TFRecord είναι ένα φορμάτ που επιτρέπει την αποθήκευση σειράς δυαδικών εγγραφών. Διαβάστε τα σχετικά λήμματα [TFRecord and tf.Example](https://www.tensorflow.org/tutorials/load_data/tfrecord) και [tf.data: Build TensorFlow input pipelines](https://www.tensorflow.org/guide/data).
#
# Σημειώστε ότι με τη μέθοδο αυτή θα πρέπει να γίνει import η `tensorflow_datasets` και να χρησιμοποιήσουμε την `tfds.load` ώστε να αποθηκευθεί το σύνολο δεδομένων σε αρχεία tfrecord στο δίσκο (δείτε [εδώ](https://colab.research.google.com/github/tensorflow/datasets/blob/master/docs/overview.ipynb) ένα παράδειγμα). Φυσικά μπορούμε να μετατρέψουμε και τα πρωτογενή δεδομένα (raw data) του dataset όπως αρχεία jpg σε φορματ tfrecord όπως [εδώ](https://towardsdatascience.com/working-with-tfrecords-and-tf-train-example-36d111b3ff4d).

# %% [markdown]
# ### Υπερεκπαίδευση
#
# Μπορείτε να πειραματιστείτε ως προς τον έλεγχο της υπερεκπαίδευσης (overfitting) με διάφορους τρόπους. Μεταξύ αυτών μπορούμε να αναφέρουμε τους εξής:
# - Πρόωρος τερματισμός (early stopping). Μια μέθοδος που τερματίζει την εκπαίδευση αν δεν υπάρχει βελτίωση ως προς τη μετρική απόδοσης που παρακολουθούμε. [tf.keras.callbacks.EarlyStopping](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStoppinghttps://)
# - Dropout. Μια άλλη τεχνική για τη μείωση της υπερεκπαίδευσης είναι το Dropout. Είναι ένα είδος ομαλοποίησης (regularization) που επιβάλλει στα βάρη του δικτύου να παίρνουν μόνο μικρές τιμές. Εάν εφαρμόσουε dropout σε ένα επίπεδο του δικτύου, τότε ένα ποσοστό των βαρών του γίνεται τυχαία μηδενικό κατά την εκπαίδευση. [Dropout](https://www.tensorflow.org/tutorials/images/classification#dropout)
# - Επαύξηση δεδομένων. Η υπερεκπαίδευση συνήθως συμβαίνει όταν έχουμε λίγα ή/και πολύ όμοια δεδομένα εκπαίδευσης. Ένας τρόπος να διορθωθεί αυτό το πρόβλημα είναι να αυξήσουμε τα δεδομένα (data augmentation). Το data augmentation δημιουργεί νέα δεδομένα εκπαίδευσης με βάση τα υπάρχοντα εφαρμόζοντας τυχαίους μετασχηματισμούς ώστε να προκύπτουν αληθοφανείς εικόνες. [Data augmentation](https://www.tensorflow.org/tutorials/images/classification#data_augmentation), [ImageDataGenerator](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator#class_imagedatagenerator)
#
# Βλέπε επίσης [Image classification](https://www.tensorflow.org/tutorials/images/classification).

# %% [markdown]
# ### Χρόνος εκπαίδευσης
#
# Το TensorFlow 2 προσφέρει νέους ή βελτιώνει διάφορους μηχανισμούς βελτιστοποίησης της εκπαίδευσης. Μεταξύ αυτών έχουμε τους εξής:
# - Data prefetching (το χρησιμοποιήσαμε παραπάνω)
# - Data reading parallelization
# - Map transformation parallelization
# - Caching
# - Reducing memory footprint
#
# Συμβουλευτείτε για τα παραπάνω το [Better performance with the tf.data API](https://www.tensorflow.org/guide/data_performance)

# %% [markdown]
# ### Εργαλεία υψηλού επιπέδου
#
# Μεταξύ των εργαλείων βελτιστοποίησης υψηλού επιπέδου (high-level) του TensorFlow μπορούμε να αναφέρουμε τα ακόλουθα:
#
# - [TensorBoard](https://www.tensorflow.org/tensorboard/get_started) και [What-If Tool](https://www.tensorflow.org/tensorboard/what_if_tool) Επικουρικό εργαλείο οπτικοποίησης/ανάλυσης για τον πειραματισμό στη εκπαίδευση
# - [tf-explain](https://tf-explain.readthedocs.io/en/latest/) Προσφέρει μεθόδους επεξηγισιμότητας για το tf2
# - [Keras Tuner](https://github.com/keras-team/keras-tuner) Βελτιστοποίηση υπερπαραμέτρων του Keras στο TensorFlow 2.0
# - [AutoAugment](https://github.com/tensorflow/models/tree/master/research/autoaugment) Εκμάθηση της πολιτικης επαύξησης από τα δεδομένα

# %% [markdown]
# # Για τις χριστουγεννιάτικες διακοπές
#
# ## What's next for Deep Learning
#
# The Godfathers of AI and 2018 ACM Turing Award winners Geoffrey Hinton, Yann LeCun, and Yoshua Bengio shared a stage in New York on Sunday night at an event organized by the Thirty-Fourth AAAI Conference on Artificial Intelligence (AAAI 2020). The trio of researchers have made deep neural networks a critical component of computing, and in individual talks and a panel discussion they discussed their views on current challenges facing deep learning and where it should be heading.

# %%
from IPython.display import IFrame
IFrame(src='https://www.youtube.com/embed/UX8OubxsY8w', width=640, height=480)
# Out:
#         <iframe
#             width="640"
#             height="480"
#             src="https://www.youtube.com/embed/UX8OubxsY8w"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Αντίλογος: η κριτική του Schmidhuber για τους LeCun & Bengio & Hinton
#
# (Ο Schmidhuber και ο Hochreiter [εισήγαγαν τα LSTM το 1997](https://www.bioinf.jku.at/publications/older/2604.pdf))
#
# *Machine learning is the science of credit assignment. The machine learning community itself profits from proper credit assignment to its members. The inventor of an important method should get credit for inventing it. She may not always be the one who popularizes it. Then the popularizer should get credit for popularizing it (but not for inventing it). Relatively young research areas such as machine learning should adopt the honor code of mature fields such as mathematics: if you have a new theorem, but use a proof technique similar to somebody else's, you must make this very clear. If you "re-invent" something that was already known, and only later become aware of this, you must at least make it clear later.*
#
# *As a case in point, let me now comment on a recent article in [Nature (2015) about "deep learning"](http://www.nature.com/nature/journal/v521/n7553/full/nature14539.html) in artificial neural networks (NNs), by LeCun & Bengio & Hinton (LBH for short), three CIFAR-funded collaborators who call themselves the "deep learning conspiracy" (e.g., LeCun, 2015). They heavily cite each other. Unfortunately, however, they fail to credit the pioneers of the field, which originated half a century ago. All references below are taken from the recent [deep learning overview](http://www.idsia.ch/~juergen/deep-learning-overview.html) (Schmidhuber, 2015), except for a few papers listed beneath this critique focusing on nine items.*
#
# [Read more...](http://people.idsia.ch/~juergen/deep-learning-conspiracy.html)
